# %% [markdown]
# # Web Crawling with Beautiful Soup

# %% [markdown]
# ## Beautiful Soup
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree.
#
# 설치 (Anaconda에는 설치되어 있음)
#
# ` pip install beautifulsoup4`

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.naver.com"
with urlopen(url) as f:
    naver = BeautifulSoup(f, "html.parser")
naver.find_all('img')[:5]
# Out:
# [<img alt="연합뉴스TV" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd154219877.png"/>,
#  <img alt="아이뉴스24" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd153955864.png"/>,
#  <img alt="서울신문" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145738195.png"/>,
#  <img alt="KBS" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd173124306.png"/>,
#  <img alt="파이낸셜뉴스" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd172557496.png"/>]

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %% [markdown]
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
# <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
# <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#
# <p class="story">...</p>

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
print(type(soup))
soup
# print(soup.prettify())
# Out:
# <class 'bs4.BeautifulSoup'>
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
soup.title         # tag
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name    # tag name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']     # attributes
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# Extracting all the URLs found within a page’s `<a>` tags:

# %%
for link in soup.find_all('a'):
    print(link.get('href'))     # 'href' attribute
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# Extracting all the text from a page:

# %%
soup.get_text()
# Out:
# "\nThe Dormouse's story\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %% [markdown]
# ## Navigating the tree

# %%
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
body_tag = soup.body
body_tag.contents
# Out:
# ['\n',
#  <p class="title"><b>The Dormouse's story</b></p>,
#  '\n',
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  '\n',
#  <p class="story">...</p>,
#  '\n']

# %% [markdown]
# ### Going down

# %%
for child in soup.body.children:    # 직계 자손을 방문하는 iterator
    print(child, end="***\n")
# Out:
# ***
# <p class="title"><b>The Dormouse's story</b></p>***
#
# ***
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>***
#
# ***
# <p class="story">...</p>***
#
# ***

# %%
for child in soup.body.descendants: # 모든 후손을 방문하는 iterator 
    print(child, end='***\n')
# Out:
# ***
# <p class="title"><b>The Dormouse's story</b></p>***
# <b>The Dormouse's story</b>***
# The Dormouse's story***
#
# ***
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>***
# Once upon a time there were three little sisters; and their names were
# ***
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>***
# Elsie***
# ,
# ***
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>***
# Lacie***
#  and
# ***
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>***
# Tillie***
# ;
# and they lived at the bottom of a well.***
#
# ***
# <p class="story">...</p>***
# ...***
#
# ***

# %% [markdown]
# ### Going up

# %%
title_tag = soup.title
title_tag.parent      # element's parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
link = soup.a
print(link)
for parent in link.parents:  # all of an element's parents
    if parent is None:
        print(parent)
    else:
        print(parent.name)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# p
# body
# html
# [document]

# %% [markdown]
# ### Going sideways

# %%
link = soup.a
link
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
for sibling in link.next_siblings:
    print(repr(sibling))
# Out:
# ',\n'
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# ' and\n'
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ';\nand they lived at the bottom of a well.'

# %%
for sibling in soup.find(id="link3").previous_siblings:
    print(repr(sibling))
# Out:
# ' and\n'
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# ',\n'
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# 'Once upon a time there were three little sisters; and their names were\n'

# %% [markdown]
# ### find_all()

# %%
soup.find_all("p", "title")
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>]

# %%
soup.find(id="link2")
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
import re
soup.find_all(id=re.compile("link"))
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# Remember that a single tag can have multiple values for its “class” attribute. When you search for a tag that matches a certain CSS class, you’re matching against any of its CSS classes:

# %%
css_soup = BeautifulSoup('<p class="body strikeout"></p>', "html.parser")
css_soup.find_all("p", class_="strikeout")
# Out:
# [<p class="body strikeout"></p>]

# %%
css_soup.find_all("p", class_="body")
# Out:
# [<p class="body strikeout"></p>]

# %% [markdown]
# ### CSS selectors
# Find tags:

# %%
soup.select("p")
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.select("p:nth-of-type(3)")
# Out:
# [<p class="story">...</p>]

# %% [markdown]
# Find tags beneath other tags:

# %%
soup.select("body a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# Find tags directly beneath other tag

# %%
soup.select("p > a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select("p > a:nth-of-type(2)")
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %%
soup.select("p > #link1")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %% [markdown]
# Find tags by CSS class

# %%
soup.select(".sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# Find tags by attribute value:

# %%
soup.select('a[href="http://example.com/elsie"]')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %% [markdown]
# ## Example

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

context = ssl._create_unverified_context()  # for https connection
url = "https://en.wikipedia.org/wiki/BTS_(band)"
with urlopen(url, context=context) as f:
    s = BeautifulSoup(f, "html.parser")

# %%
for tag in s.find_all('a'):
    href = tag.get("href")
    if href is not None:
        print(href, tag.text)
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head Jump to navigation
# #p-search Jump to search
# /wiki/File:ROK_Order_of_Cultural_Merit_Hwa-gwan_(5th_Class)_ribbon.PNG
# /wiki/Order_of_Cultural_Merit_(Korea) Hwagwan Order of Cultural Merit
# /wiki/File:%E2%80%98LG_Q7_BTS_%EC%97%90%EB%94%94%EC%85%98%E2%80%99_%EC%98%88%EC%95%BD_%ED%8C%90%EB%A7%A4_%EC%8B%9C%EC%9E%91_(42773472410)_(cropped).jpg
# /wiki/LG_Electronics LG Electronics
# /wiki/V_(singer) V
# /wiki/J-Hope J-Hope
# /wiki/RM_(rapper) RM
# /wiki/Kim_Seok-jin Jin
# /wiki/Jimin_(singer,_born_1995) Jimin
# /wiki/Jungkook Jungkook
# /wiki/Suga_(rapper) Suga
# /wiki/Seoul Seoul
# /wiki/K-pop K-pop
# /wiki/Hip_hop_music hip hop
# /wiki/Contemporary_R%26B R&B
# /wiki/Electronic_dance_music EDM
# /wiki/Big_Hit_Entertainment Big Hit
# /wiki/Pony_Canyon Pony Canyon
# /wiki/Def_Jam_Recordings Def Jam Japan
# #cite_note-1 [1]
# /wiki/Columbia_Records Columbia
# #cite_note-2 [2]
# http://bts.ibighit.com bts.ibighit.com
# /wiki/Kim_Seok-jin Jin
# /wiki/Suga_(rapper) Suga
# /wiki/J-Hope J-Hope
# /wiki/RM_(rapper) RM
# /wiki/Jimin_(singer,_born_1995) Jimin
# /wiki/V_(singer) V
# /wiki/Jungkook Jungkook
# /wiki/Hangul Hangul
# https://en.wiktionary.org/wiki/%EB%B0%A9%ED%83%84 방탄
# https://en.wiktionary.org/wiki/%EC%86%8C%EB%85%84 소년
# https://en.wiktionary.org/wiki/%EB%8B%A8 단
# /wiki/Hanja Hanja
# https://en.wiktionary.org/wiki/%E9%98%B2%E5%BD%88 防彈
# https://en.wiktionary.org/wiki/%E5%B0%91%E5%B9%B4 少年
# https://en.wiktionary.org/wiki/%E5%9C%98 團
# /wiki/Revised_Romanization_of_Korean Revised Romanization
# /wiki/McCune%E2%80%93Reischauer McCune–Reischauer
# /wiki/Kanji Kanji
# /wiki/Hiragana Hiragana
# /wiki/Hepburn_romanization Revised Hepburn
# /wiki/Kunrei-shiki_romanization Kunrei-shiki
# /wiki/Hangul Hangul
# /wiki/Revised_Romanization_of_Korean RR
# /wiki/Boy_band boy band
# /wiki/Seoul Seoul
# /wiki/Backronym backronym
# /wiki/Hip_hop_music hip hop
# /wiki/Parallel_universes_in_fiction alternative universe
# /wiki/Big_Hit_Entertainment Big Hit Entertainment
# /wiki/2_Cool_4_Skool 2 Cool 4 Skool
# /wiki/Billboard_200 Billboard
# /wiki/Billboard_200 200
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_2 The Most Beautiful Moment in Life, Part 2
# /wiki/The_Most_Beautiful_Moment_in_Life:_Young_Forever The Most Beautiful Moment in Life: Young Forever
# /wiki/Wings_(BTS_album) Wings
# /wiki/Korean_Wave Korean Wave
# /wiki/Recording_Industry_Association_of_America RIAA
# /wiki/DNA_(BTS_song) DNA
# /wiki/Mic_Drop_(song) Mic Drop
# /wiki/Psy Psy
# //en.wikipedia.org/w/index.php?title=BTS_(band)&action=edit [update]
# /wiki/Billboard_200 Billboard
# /wiki/Billboard_200 200
# /wiki/Love_Yourself:_Tear Love Yourself 轉 'Tear'
# /wiki/Love_Yourself:_Answer Love Yourself 結 'Answer'
# /wiki/Map_of_the_Soul:_Persona Map of the Soul: Persona
# /wiki/The_Beatles The Beatles
# /wiki/Love_Yourself_%E7%B5%90_%27Answer%27 Love Yourself 結 'Answer'
# /wiki/Love_Yourself_%E8%BD%89_%27Tear%27 Love Yourself 轉 'Tear'
# /wiki/Drake_(musician) Drake
# /wiki/Guinness_World_Records Guinness World Record
# /wiki/Twitter Twitter
# /wiki/Billboard_Music_Award_for_Top_Social_Artist Top Social Artist
# /wiki/2017_Billboard_Music_Awards Billboard Music Awards
# /wiki/Time_(magazine) Time
# /wiki/Time_100 Time 100
# /wiki/Forbes_Korea_Power_Celebrity Forbes Korea Power Celebrity
# /wiki/United_Nations United Nations
# /wiki/United_Nations_General_Assembly General Assembly
# /wiki/Order_of_Cultural_Merit_(Korea) Order of Cultural Merit
# #Name 1 Name
# #Career 2 Career
# #2010–2014:_Formation_and_early_years 2.1 2010–2014: Formation and early years
# #2014–2015:_Moderate_success_and_first_concert_tour 2.2 2014–2015: Moderate success and first concert tour
# #2015–2016:_Mainstream_breakthrough_and_commercial_success 2.3 2015–2016: Mainstream breakthrough and commercial success
# #2017:_International_expansion_and_collaborations 2.4 2017: International expansion and collaborations
# #2018:_Worldwide_recognition 2.5 2018: Worldwide recognition
# #2019:_Map_of_the_Soul:_Persona_and_stadium_world_tour 2.6 2019: Map of the Soul: Persona and stadium world tour
# #Artistry 3 Artistry
# #Music 3.1 Music
# #Lyrics_and_themes 3.2 Lyrics and themes
# #Influences 3.3 Influences
# #Impact_and_influence 4 Impact and influence
# #Awards_and_achievements 5 Awards and achievements
# #Other_ventures 6 Other ventures
# #Endorsements 6.1 Endorsements
# #Philanthropy 6.2 Philanthropy
# #BTS_Universe 6.3 BTS Universe
# #Members 7 Members
# #Discography 8 Discography
# #Tours_and_concerts 9 Tours and concerts
# #Filmography 10 Filmography
# #Exhibitions 10.1 Exhibitions
# #Film 10.2 Film
# #Television 10.3 Television
# #Variety_shows_on_V_Live 10.4 Variety shows on V Live
# #References 11 References
# #External_links 12 External links
# /wiki/File:BTS_LOGO_(3).png
# /wiki/File:BTS_LOGO_(3).png
# #cite_note-:9-3 [3]
# /wiki/Hangul Hangul
# /wiki/Hanja Hanja
# https://en.wiktionary.org/wiki/%E9%98%B2%E5%BD%88 防彈
# https://en.wiktionary.org/wiki/%E5%B0%91%E5%B9%B4 少年
# https://en.wiktionary.org/wiki/%E5%9C%98 團
# /wiki/J-Hope J-Hope
# #cite_note-4 [4]
# #cite_note-5 [5]
# #cite_note-6 [6]
# #cite_note-newname-7 [7]
# #cite_note-:9-3 [3]
# /wiki/File:Bangtan_Boys_at_the_Incheon_Music_Center_in_September_2013_02.jpg
# /wiki/File:Bangtan_Boys_at_the_Incheon_Music_Center_in_September_2013_02.jpg
# /wiki/Incheon Incheon
# /wiki/Bang_Si-hyuk Bang Si-hyuk
# /wiki/RM_(rapper) RM
# #cite_note-8 [8]
# /wiki/1TYM 1TYM
# #cite_note-:0-9 [9]
# #cite_note-10 [10]
# /wiki/2AM_(band) 2AM
# /wiki/Lee_Seung-gi Lee Seung-gi
# #cite_note-11 [11]
# /wiki/Kim_Seok-jin Jin
# /wiki/Suga_(rapper) Suga
# /wiki/J-Hope J-Hope
# /wiki/RM_(rapper) RM
# /wiki/Jimin_(singer,_born_1995) Jimin
# /wiki/V_(singer) V
# /wiki/Jungkook_(singer) Jungkook
# /wiki/YouTube YouTube
# /wiki/SoundCloud SoundCloud
# #cite_note-12 [12]
# #cite_note-13 [13]
# /wiki/Suga Suga
# #cite_note-14 [14]
# /wiki/Single_(music)#In_South_Korea single album
# /wiki/2_Cool_4_Skool 2 Cool 4 Skool
# #cite_note-15 [15]
# #cite_note-16 [16]
# #cite_note-17 [17]
# #cite_note-18 [18]
# #cite_note-BTSReview-19 [19]
# #cite_note-:3-20 [20]
# #cite_note-BTSReview-19 [19]
# #cite_note-:3-20 [20]
# #cite_note-:4-21 [21]
# #cite_note-22 [22]
# #cite_note-:4-21 [21]
# #cite_note-Japan_Debut-23 [23]
# /wiki/Extended_play extended play
# /wiki/O!RUL8,2%3F O!RUL8,2?
# #cite_note-24 [24]
# #cite_note-25 [25]
# #cite_note-26 [26]
# #cite_note-27 [27]
# /wiki/SBS_MTV SBS MTV
# /wiki/MasterChef_Korea MasterChef Korea
# #cite_note-28 [28]
# /wiki/Melon_Music_Awards Melon Music Awards
# /wiki/Golden_Disc_Awards Golden Disc Awards
# /wiki/Seoul_Music_Awards Seoul Music Awards
# #cite_note-29 [29]
# /wiki/File:Troubadour_02.jpg
# /wiki/File:Troubadour_02.jpg
# /wiki/Troubadour_(West_Hollywood,_California) Troubadour
# /wiki/United_States United States
# /wiki/Skool_Luv_Affair Skool Luv Affair
# #cite_note-sla-30 [30]
# /wiki/Gaon_Album_Chart Gaon Album Chart
# #cite_note-31 [31]
# /wiki/Billboard_(magazine) Billboard
# #cite_note-sla-30 [30]
# #cite_note-World_chart-32 [32]
# #cite_note-33 [33]
# #cite_note-34 [34]
# /wiki/Seoul Seoul
# #cite_note-35 [35]
# #cite_note-36 [36]
# /wiki/West_Hollywood,_California West Hollywood
# #cite_note-37 [37]
# /wiki/KCON_(music_festival) KCON
# /wiki/Los_Angeles Los Angeles
# #cite_note-38 [38]
# #cite_note-39 [39]
# /wiki/Dark_%26_Wild Dark & Wild
# #cite_note-40 [40]
# #cite_note-41 [41]
# /wiki/Rock_music rock
# /wiki/Rhythm_and_blues R&B
# #cite_note-:15-42 [42]
# #cite_note-43 [43]
# #cite_note-44 [44]
# /wiki/Concert_tour concert tour
# /wiki/Kobe Kobe
# /wiki/Tokyo Tokyo
# /wiki/Manila Manila
# /wiki/Singapore Singapore
# /wiki/Bangkok Bangkok
# #cite_note-TRB_II-45 [45]
# /wiki/Wake_Up_(BTS_album) Wake Up
# /wiki/Oricon_Albums_Chart Oricon Albums Chart
# #cite_note-oricon-46 [46]
# #cite_note-47 [47]
# #cite_note-48 [48]
# #cite_note-BTS_Begin-49 [49]
# #cite_note-Review6-50 [50]
# #cite_note-:5-51 [51]
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_1 The Most Beautiful Moment in Life, Part 1
# #cite_note-:5-51 [51]
# #cite_note-52 [52]
# #cite_note-Review6-50 [50]
# /wiki/Fuse_(TV_channel) Fuse
# #cite_note-53 [53]
# #cite_note-54 [54]
# /wiki/I_Need_U_(BTS_song) I Need U
# #cite_note-55 [55]
# /wiki/SBS_MTV SBS MTV
# /wiki/The_Show_(South_Korean_TV_series) The Show
# #cite_note-INU_Wins-56 [56]
# #cite_note-57 [57]
# /wiki/YouTube YouTube
# #cite_note-Dope_100mil-58 [58]
# #cite_note-59 [59]
# #cite_note-60 [60]
# /wiki/2015_BTS_Live_Trilogy_Episode_II:_The_Red_Bullet 2015 Live Trilogy Episode: The Red Bullet
# #cite_note-TRB_II-45 [45]
# /wiki/Oricon_Albums_Chart Oricon
# #cite_note-For_You_Oricon-61 [61]
# /wiki/Summer_Sonic_Festival Summer Sonic Festival
# #cite_note-62 [62]
# #cite_note-63 [63]
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_2 The Most Beautiful Moment in Life, Part 2
# #cite_note-64 [64]
# #cite_note-:16-65 [65]
# /wiki/Billboard_(magazine) Billboard
# /wiki/World_Albums World Albums
# #cite_note-66 [66]
# #cite_note-67 [67]
# /wiki/Billboard_200_chart Billboard 200
# #cite_note-68 [68]
# /wiki/2015_Mnet_Asian_Music_Awards 17th Mnet Asian Music Awards
# /wiki/Mnet_Asian_Music_Awards_in_the_Special_Awards_Category Best World Performer
# /wiki/File:Bangtan_Boys_at_KCON_France_2016.jpg
# /wiki/File:Bangtan_Boys_at_KCON_France_2016.jpg
# /wiki/KCON_(music_festival) KCON
# /wiki/The_Most_Beautiful_Moment_in_Life:_Young_Forever The Most Beautiful Moment in Life: Young Forever
# /wiki/Fire_(BTS_song) Fire
# /wiki/Save_Me_(BTS_song) Save Me
# #cite_note-69 [69]
# #cite_note-70 [70]
# /wiki/List_of_Gaon_Album_Chart_number_ones_of_2016#Weekly_charts Gaon Weekly Chart
# /wiki/Billboard_200 Billboard 200
# #cite_note-71 [71]
# #cite_note-72 [72]
# #cite_note-73 [73]
# #cite_note-74 [74]
# /wiki/Daesang daesang
# /wiki/Melon_Music_Awards Melon Music Awards
# #cite_note-75 [75]
# #cite_note-76 [76]
# /wiki/Olympic_Gymnastics_Arena Olympic Gymnastics Arena
# /wiki/Seoul Seoul
# #cite_note-May_2016_Comeback-77 [77]
# /wiki/KCON_(music_festival) KCON
# /wiki/Newark,_New_Jersey Newark
# #cite_note-78 [78]
# #cite_note-Kcon_2016-79 [79]
# /wiki/File:BTS_win_first_Daesang_(Grand_Prize)_at_Melon_Music_Awards,_19_November_2016.jpg
# /wiki/File:BTS_win_first_Daesang_(Grand_Prize)_at_Melon_Music_Awards,_19_November_2016.jpg
# /wiki/Youth_(BTS_album) Youth
# #cite_note-INU_Japanese-80 [80]
# /wiki/Japan Japan
# #cite_note-81 [81]
# /wiki/Wings_(BTS_album) Wings
# #cite_note-500k_presale-82 [82]
# #cite_note-Review10-83 [83]
# /wiki/Rolling_Stone Rolling Stone
# #cite_note-84 [84]
# /wiki/Fuse_(TV_channel) Fuse
# #cite_note-85 [85]
# #cite_note-86 [86]
# #cite_note-87 [87]
# #cite_note-BST_Youtube_Records-88 [88]
# /wiki/Gaon_Album_Chart Gaon Album Chart
# #cite_note-89 [89]
# #cite_note-90 [90]
# #cite_note-91 [91]
# /wiki/List_of_Billboard_Social_50_number-one_artists Social 50
# #cite_note-92 [92]
# /wiki/Mnet_Asian_Music_Awards Mnet Asian Music Awards
# #cite_note-93 [93]
# /wiki/S.M._Entertainment SM
# /wiki/YG_Entertainment YG
# /wiki/JYP_Entertainment JYP
# #cite_note-94 [94]
# /wiki/Wings_(BTS_album)#You_Never_Walk_Alone You Never Walk Alone
# #cite_note-95 [95]
# #cite_note-96 [96]
# #cite_note-:03-97 [97]
# /wiki/Spring_Day_(song) Spring Day
# /wiki/Dazed_Digital Dazed Digital
# #cite_note-98 [98]
# #cite_note-Review10-83 [83]
# #cite_note-99 [99]
# #cite_note-100 [100]
# /wiki/Melon_(online_music_service) Melon
# #cite_note-101 [101]
# /wiki/Bubbling_Under_Hot_100 Bubbling Under Hot 100
# #cite_note-102 [102]
# #cite_note-103 [103]
# /wiki/Melon_Music_Awards#Song_of_the_Year Melon Music Awards
# #cite_note-104 [104]
# #cite_note-105 [105]
# /wiki/File:170529_BTS_at_a_press_conference_for_the_BBMAs_(3).png
# /wiki/File:170529_BTS_at_a_press_conference_for_the_BBMAs_(3).png
# /wiki/2017_BTS_Live_Trilogy_Episode_III:_The_Wings_Tour 2017 BTS Live Trilogy Episode III: The Wings Tour
# #cite_note-TotalNumbers2-106 [106]
# #cite_note-107 [107]
# #cite_note-108 [108]
# /wiki/Billboard_Music_Award Billboard Music Awards
# /wiki/Billboard_Music_Award_for_Top_Social_Artist Top Social Artist
# #cite_note-109 [109]
# /wiki/Seo_Taiji Seo Taiji
# /wiki/Come_Back_Home_(Seo_Taiji_and_Boys_song) Come Back Home
# #cite_note-110 [110]
# /wiki/Seoul_Olympic_Stadium Seoul Olympic Stadium
# #cite_note-111 [111]
# #cite_note-112 [112]
# #cite_note-:6-113 [113]
# /wiki/Love_Yourself:_Her Love Yourself 承 'Her'
# #cite_note-114 [114]
# /wiki/The_Chainsmokers the Chainsmokers
# #cite_note-115 [115]
# /wiki/DNA_(BTS_song) DNA
# /wiki/Steve_Aoki Steve Aoki
# /wiki/Mic_Drop_(song) Mic Drop
# /wiki/Desiigner Desiigner
# #cite_note-116 [116]
# #cite_note-:6-113 [113]
# #cite_note-117 [117]
# #cite_note-118 [118]
# /wiki/G.o.d g.o.d
# /wiki/Chapter_4_(g.o.d_album) Chapter 4
# #cite_note-119 [119]
# /wiki/YouTube YouTube
# #cite_note-120 [120]
# /wiki/Billboard_Hot_100 Billboard Hot 100
# #cite_note-121 [121]
# /wiki/Wonder_Girls Wonder Girls
# #cite_note-122 [122]
# /wiki/Mic_Drop_(song) Mic Drop (Remix)
# #cite_note-123 [123]
# #cite_note-124 [124]
# #cite_note-125 [125]
# /wiki/Recording_Industry_Association_of_America Recording Industry Association of America
# #cite_note-126 [126]
# #cite_note-127 [127]
# #cite_note-:7-128 [128]
# #cite_note-129 [129]
# #cite_note-130 [130]
# #cite_note-131 [131]
# #cite_note-132 [132]
# #cite_note-133 [133]
# #cite_note-134 [134]
# #cite_note-135 [135]
# #cite_note-136 [136]
# /wiki/File:BTS_at_2017_American_Music_Awards_in_Los_Angeles,_19_November_2017_02.jpg
# /wiki/File:BTS_at_2017_American_Music_Awards_in_Los_Angeles,_19_November_2017_02.jpg
# /wiki/American_Music_Awards American Music Awards
# #cite_note-137 [137]
# #cite_note-138 [138]
# #cite_note-139 [139]
# #cite_note-140 [140]
# /wiki/Guinness_World_Records Guinness World Records
# #cite_note-141 [141]
# /wiki/Dick_Clark%27s_New_Year%27s_Rockin%27_Eve Dick Clark's New Year's Rockin' Eve
# #cite_note-142 [142]
# /wiki/TV_Asahi TV Asahi
# /wiki/Music_Station#Super_Live Japan Music Station Super Live
# #cite_note-143 [143]
# /wiki/Mnet_Asian_Music_Award_for_Artist_of_the_Year Artist of the Year
# /wiki/2017_Mnet_Asian_Music_Awards 19th Mnet Asian Music Awards
# #cite_note-144 [144]
# #cite_note-145 [145]
# #cite_note-146 [146]
# /wiki/Golden_Disc_Awards Golden Disc Awards
# #cite_note-147 [147]
# /wiki/Seoul_Music_Awards Seoul Music Awards
# #cite_note-148 [148]
# /wiki/YouTube_Premium YouTube Premium
# #cite_note-149 [149]
# #cite_note-150 [150]
# /wiki/Face_Yourself Face Yourself
# #cite_note-151 [151]
# /wiki/Billboard_200 Billboard 200
# #cite_note-152 [152]
# #cite_note-:8-153 [153]
# /wiki/File:180524_BTS_at_a_press_conference_for_Love_Yourself_Tear_(3).png
# /wiki/File:180524_BTS_at_a_press_conference_for_Love_Yourself_Tear_(3).png
# /wiki/Love_Yourself:_Tear Love Yourself 轉 'Tear'
# /wiki/2018_Billboard_Music_Awards 26th Billboard Music Awards
# #cite_note-154 [154]
# /wiki/Fake_Love_(BTS_song) Fake Love
# #cite_note-155 [155]
# /wiki/Billboard_Music_Award_for_Top_Social_Artist Top Social Artist
# #cite_note-156 [156]
# #cite_note-157 [157]
# #cite_note-158 [158]
# /wiki/Billboard_(magazine) Billboard
# #cite_note-159 [159]
# /wiki/Pitchfork_(website) Pitchfork
# #cite_note-160 [160]
# /wiki/Album-equivalent_unit album-equivalent units
# #cite_note-161 [161]
# #cite_note-162 [162]
# /wiki/United_Kingdom United Kingdom
# /wiki/UK_Albums_Chart UK Albums Chart
# #cite_note-163 [163]
# #cite_note-164 [164]
# #cite_note-165 [165]
# #cite_note-166 [166]
# /wiki/Compilation_album compilation album
# /wiki/Love_Yourself:_Answer Love Yourself 結 'Answer'
# #cite_note-167 [167]
# #cite_note-168 [168]
# /wiki/Idol_(BTS_song) Idol
# /wiki/Nicki_Minaj Nicki Minaj
# #cite_note-169 [169]
# #cite_note-170 [170]
# #cite_note-:10-171 [171]
# /wiki/Billboard_(magazine) Billboard
# /wiki/Magnum_opus magnum opus
# #cite_note-172 [172]
# /wiki/Gaon_Album_Chart Gaon Album Chart
# #cite_note-173 [173]
# #cite_note-BB200-174 [174]
# /wiki/Pop_music pop
# /wiki/One_Direction One Direction
# /wiki/Midnight_Memories Midnight Memories
# /wiki/Four_(One_Direction_album) Four
# #cite_note-BB200-174 [174]
# #cite_note-:7-128 [128]
# /wiki/Canadian_Albums_Chart Canadian Albums Chart
# /wiki/Billboard_Hot_100 Billboard Hot 100
# #cite_note-175 [175]
# /wiki/Canadian_Singles_Chart Canadian Singles Chart
# #cite_note-176 [176]
# /wiki/Taylor_Swift Taylor Swift
# /wiki/Look_What_You_Made_Me_Do Look What You Made Me Do
# #cite_note-177 [177]
# /wiki/File:Le_Citi_Field.jpg
# /wiki/File:Le_Citi_Field.jpg
# /wiki/Citi_Field Citi Field,
# /wiki/Love_Yourself_%E7%B5%90_%27Answer%27 Love Yourself 結 'Answer'
# /wiki/BTS_World_Tour:_Love_Yourself BTS World Tour: Love Yourself
# /wiki/Seoul_Olympic_Stadium Seoul Olympic Stadium
# #cite_note-178 [178]
# /wiki/Steve_Aoki Steve Aoki
# /wiki/Waste_It_On_Me Waste It On Me
# #cite_note-179 [179]
# #cite_note-180 [180]
# /wiki/Citi_Field Citi Field
# #cite_note-181 [181]
# #cite_note-182 [182]
# /wiki/StubHub StubHub
# /wiki/Ed_Sheeran Ed Sheeran
# #cite_note-183 [183]
# /wiki/Vivid_Seats Vivid Seats
# /wiki/Citi_Field Citi Field
# #cite_note-184 [184]
# /wiki/Uproxx Uproxx
# /wiki/Staples_Center Staples Center
# #cite_note-:02-185 [185]
# /wiki/MTV MTV
# #cite_note-CF1-186 [186]
# #cite_note-187 [187]
# #cite_note-188 [188]
# /wiki/Simon_Wiesenthal_Center Simon Wiesenthal Center
# #cite_note-189 [189]
# /wiki/Nazism Nazism
# #cite_note-190 [190]
# #cite_note-191 [191]
# #cite_note-192 [192]
# /wiki/Burn_the_Stage:_The_Movie Burn the Stage: The Movie
# #cite_note-193 [193]
# /wiki/2018_Mnet_Asian_Music_Awards 20th Mnet Asian Music Awards
# #cite_note-194 [194]
# /wiki/Drake_(musician) Drake
# /wiki/Taylor_Swift Taylor Swift
# /wiki/Imagine_Dragons Imagine Dragons
# #cite_note-195 [195]
# /wiki/50_Most_Influential_(Bloomberg_Markets_ranking) the Bloomberg 50
# #cite_note-196 [196]
# #cite_note-197 [197]
# /wiki/File:Wembley_Stadium_interior.jpg
# /wiki/File:Wembley_Stadium_interior.jpg
# /wiki/Wembley_Stadium Wembley Stadium
# /wiki/61st_Grammy_Awards 61st Grammy Awards
# #cite_note-198 [198]
# #cite_note-199 [199]
# /wiki/Grammy_Museum_at_L.A._Live LA Grammy Museum
# #cite_note-200 [200]
# #cite_note-201 [201]
# /wiki/BTS_World_Tour_Love_Yourself:_Speak_Yourself Love Yourself: Speak Yourself
# /wiki/Wembley_Stadium Wembley Stadium
# /wiki/Stade_de_France Stade de France
# /wiki/MetLife_Stadium MetLife Stadium
# /wiki/Rose_Bowl_(stadium) Rose Bowl
# /wiki/Soldier_Field Soldier Field
# #cite_note-SYextension-202 [202]
# #cite_note-203 [203]
# /wiki/Spotify Spotify
# #cite_note-204 [204]
# /wiki/Time_(magazine) Time
# /wiki/Time_100 Time 100
# #cite_note-205 [205]
# /wiki/Map_of_the_Soul:_Persona Map of the Soul: Persona
# /wiki/Boy_With_Luv Boy With Luv
# /wiki/Halsey_(singer) Halsey
# #cite_note-206 [206]
# /wiki/Saturday_Night_Live Saturday Night Live
# #cite_note-207 [207]
# #cite_note-208 [208]
# #cite_note-209 [209]
# #cite_note-210 [210]
# /wiki/The_Beatles The Beatles
# #cite_note-211 [211]
# #cite_note-212 [212]
# #cite_note-213 [213]
# #cite_note-214 [214]
# #cite_note-215 [215]
# /wiki/Hip_hop hip hop
# #cite_note-:17-216 [216]
# #cite_note-:0-9 [9]
# #cite_note-217 [217]
# #cite_note-:17-216 [216]
# /wiki/Old-school_hip_hop old-school hip hop
# #cite_note-BTSReview-19 [19]
# /wiki/Rhythm_and_blues R&B
# /wiki/Rock_music rock
# #cite_note-mtviggy.com-218 [218]
# #cite_note-:15-42 [42]
# /wiki/Electronic_dance_music electronic dance music
# #cite_note-:16-65 [65]
# /wiki/Moombahton moombahton
# /wiki/Neo_soul neo soul
# /wiki/Gospel_music gospel
# #cite_note-Vapp-219 [219]
# #cite_note-Review10-83 [83]
# /wiki/Future_bass future bass
# /wiki/Latin_pop Latin pop
# /wiki/Jazz_rap jazz hip hop
# #cite_note-:6-113 [113]
# /wiki/No_More_Dream No More Dream
# /wiki/N.O_(BTS_song) N.O
# #cite_note-:11-220 [220]
# /wiki/Dope_(BTS_song) Dope
# /wiki/Silver_Spoon_(BTS_song) Silver Spoon
# /wiki/Millennials millennial
# #cite_note-:11-220 [220]
# /wiki/Am_I_Wrong_(BTS_song) Am I Wrong
# /wiki/Wings_(BTS_album) Wings
# /wiki/Ministry_of_Education_(South_Korea) Ministry of Education
# /wiki/Caste caste system
# /wiki/2016_South_Korean_political_scandal 2016 South Korean political scandal
# /wiki/Park_Geun-hye Park Geun-hye
# #cite_note-:11-220 [220]
# /wiki/Skool_Luv_Affair Tomorrow
# /wiki/The_Most_Beautiful_Moment_in_Life,_Pt._1 Intro: The Most Beautiful Moment in Life
# /wiki/Forever_Rain Forever Rain
# #cite_note-221 [221]
# #cite_note-222 [222]
# /wiki/Not_Today_(BTS_song) Not Today
# /wiki/Anti-establishment anti-establishment
# #cite_note-Not_Today-223 [223]
# /wiki/Spring_Day_(song) Spring Day
# /wiki/Sinking_of_MV_Sewol Sewol Ferry tragedy
# #cite_note-224 [224]
# #cite_note-:9-3 [3]
# #cite_note-:2-225 [225]
# #cite_note-:2-225 [225]
# /wiki/Wings_(BTS_album) Wings
# #cite_note-:1-226 [226]
# #cite_note-:10-171 [171]
# #cite_note-:3-20 [20]
# #cite_note-227 [227]
# /wiki/RM_(rapper) RM
# #cite_note-:12-228 [228]
# /wiki/Suga_(rapper) Suga
# #cite_note-:12-228 [228]
# /wiki/Fuse_(magazine) Fuse magazine
# #cite_note-:03-97 [97]
# /wiki/Moon_Jae-in Moon Jae-in
# #cite_note-229 [229]
# /wiki/Nas Nas
# /wiki/Eminem Eminem
# /wiki/Kanye_West Kanye West
# /wiki/Drake_(musician) Drake
# /wiki/Post_Malone Post Malone
# /wiki/Charlie_Puth Charlie Puth
# #cite_note-230 [230]
# /wiki/Hermann_Hesse Hermann Hesse's
# /wiki/Demian Demian
# #cite_note-231 [231]
# /wiki/Blood_Sweat_%26_Tears_(song) Blood Sweat and Tears
# /wiki/Friedrich_Nietzsche Friedrich Nietzsche
# /wiki/Thus_Spoke_Zarathustra Thus Spoke Zurathustra
# /wiki/Herbert_James_Draper Herbert James Draper
# /wiki/The_Lament_for_Icarus The Lament for Icarus
# /wiki/Pieter_Bruegel_the_Elder Pieter Bruegel
# /wiki/Landscape_with_the_Fall_of_Icarus Landscape with the Fall of Icarus
# /wiki/The_Fall_of_the_Rebel_Angels_(Bruegel) The Fall of the Rebel Angels
# #cite_note-232 [232]
# /wiki/Ursula_K._Le_Guin Ursula Le Guin
# /wiki/The_Ones_Who_Walk_Away_from_Omelas The Ones Who Walk Away from Omelas
# #cite_note-233 [233]
# /wiki/Erich_Fromm Erich Fromm
# /wiki/The_Art_of_Loving The Art of Loving
# #cite_note-234 [234]
# /wiki/James_Doty_(physician) James R. Doty
# #cite_note-235 [235]
# #cite_note-236 [236]
# /wiki/File:BTS_performing_at_the_Korea-France_Friendship_Concert,_Paris_Treasure_Art_Theater,_14_October_2018.jpg
# /wiki/File:BTS_performing_at_the_Korea-France_Friendship_Concert,_Paris_Treasure_Art_Theater,_14_October_2018.jpg
# #cite_note-237 [237]
# #cite_note-238 [238]
# #cite_note-239 [239]
# /wiki/Drake_(musician) Drake
# #cite_note-GAC-240 [240]
# #cite_note-241 [241]
# #cite_note-242 [242]
# #cite_note-243 [243]
# /wiki/Time_(magazine) Time
# #cite_note-244 [244]
# #cite_note-245 [245]
# /wiki/Time_100 Time 100
# #cite_note-:14-246 [246]
# /wiki/Forbes_Korea_Power_Celebrity Forbes Korea Power Celebrity
# #cite_note-247 [247]
# #cite_note-KForbes-248 [248]
# /wiki/United_Nations United Nations
# /wiki/United_Nations_General_Assembly General Assembly
# #cite_note-:13-249 [249]
# #cite_note-RSIUN-250 [250]
# /wiki/Moon_Jae-in Moon Jae-in
# /wiki/France France
# /wiki/South_Korea South Korea
# #cite_note-251 [251]
# /wiki/Order_of_Cultural_Merit_(Korea) Order of Cultural Merit
# #cite_note-herald-252 [252]
# #cite_note-253 [253]
# #cite_note-254 [254]
# /wiki/Korean_Wave Hallyu Movement
# /wiki/Korea_Customs_Service Korea Customs Service
# /wiki/Korea_Foundation Korea Foundation
# #cite_note-255 [255]
# /wiki/Korea_Creative_Content_Agency KOCCA
# #cite_note-256 [256]
# /wiki/Billboard_200 Billboard 200
# #cite_note-257 [257]
# #cite_note-258 [258]
# #cite_note-259 [259]
# /wiki/Netmarble Netmarble
# /wiki/Soribada Soribada
# /wiki/Mattel Mattel
# #cite_note-260 [260]
# #cite_note-Mattell-261 [261]
# #cite_note-262 [262]
# #cite_note-263 [263]
# /wiki/Ariana_Grande Ariana Grande
# /wiki/Drake_(musician) Drake
# #cite_note-264 [264]
# /wiki/(G)I-dle (G)I-dle
# #cite_note-265 [265]
# /wiki/D-Crunch D-Crunch
# #cite_note-266 [266]
# /wiki/The_Boyz_(South_Korean_band) The Boyz'
# #cite_note-267 [267]
# /wiki/SF9_(band) SF9's
# #cite_note-268 [268]
# /wiki/Euna_Kim Euna Kim
# #cite_note-269 [269]
# /wiki/Golden_Child_(band) Golden Child's
# #cite_note-270 [270]
# /wiki/Wanna_One Wanna One
# #cite_note-271 [271]
# /wiki/In2It IN2IT
# #cite_note-272 [272]
# /wiki/Park_Ji-hoon Park Ji-hoon
# #cite_note-273 [273]
# /wiki/Kim_Dong-han Kim Dong-han
# #cite_note-274 [274]
# #cite_note-275 [275]
# /wiki/Seven_O%27Clock_(band) Seven O'Clock
# #cite_note-276 [276]
# /wiki/Hyeongseop_X_Euiwoong Hyeongseop X Euiwoong
# #cite_note-277 [277]
# /wiki/Noir_(band) Noir
# #cite_note-278 [278]
# /wiki/Victon Victon
# #cite_note-279 [279]
# /wiki/Loona_(group) Loona
# #cite_note-280 [280]
# /wiki/Idol_(BTS_song) Idol
# /wiki/National_Gugak_Center National Gugak Center
# #cite_note-281 [281]
# /wiki/RM_(rapper) RM
# /wiki/United_Nations United Nations
# #cite_note-282 [282]
# /wiki/List_of_awards_and_nominations_received_by_BTS List of awards and nominations received by BTS
# /wiki/Melon_Music_Awards Melon Music Awards
# /wiki/Mnet_Asian_Music_Awards Mnet Asian Music Awards
# /wiki/Golden_Disc_Awards Golden Disc Awards
# /wiki/Seoul_Music_Awards Seoul Music Awards
# /wiki/Gaon_Chart_Music_Awards Gaon Chart Music Awards
# /wiki/Korean_Music_Awards Korean Music Awards
# /wiki/Billboard_Music_Award Billboard Music Awards
# /wiki/American_Music_Awards American Music Award
# /wiki/Gaon_Music_Chart#Certification Multi-Million album
# /wiki/Gaon_Music_Chart#Certification Million album
# #cite_note-283 [283]
# /wiki/Recording_Industry_Association_of_America RIAA
# /wiki/Platinum_Single Platinum single
# /wiki/Gold_single Gold singles
# /wiki/Gold_album Gold album
# #cite_note-284 [284]
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification Multi-Platinum singles
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification Multi-Platinum album
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification Gold albums
# /wiki/Guinness_World_Records Guinness World Records
# #cite_note-285 [285]
# /wiki/Order_of_Cultural_Merit_(Korea) Order of Cultural Merit
# /wiki/President_of_South_Korea President of South Korea
# #cite_note-herald-252 [252]
# /wiki/Time_100 Time 100
# #cite_note-:14-246 [246]
# /wiki/Puma_(brand) Puma
# #cite_note-286 [286]
# #cite_note-287 [287]
# #cite_note-288 [288]
# #cite_note-289 [289]
# /wiki/LG_Electronics LG Electronics
# /wiki/LG_G7_ThinQ LG G7 ThinQ
# #cite_note-290 [290]
# /wiki/Hyundai_Motor_Company Hyundai Motor
# /wiki/LA_Auto_Show LA Auto Show
# /wiki/Hyundai_Palisade Palisade
# #cite_note-291 [291]
# #cite_note-292 [292]
# /wiki/Lotte_Corporation Lotte
# #cite_note-293 [293]
# /wiki/Seoul_Metropolitan_Government Seoul Metropolitan Government
# #cite_note-294 [294]
# /wiki/Line_(software) Line
# /wiki/Line_Friends Line 'characters'
# /wiki/Line_Friends#BT21 BT21
# #cite_note-295 [295]
# #cite_note-296 [296]
# /wiki/File:Line_FriendsStore_BT21_04.jpg
# /wiki/File:Line_FriendsStore_BT21_04.jpg
# /wiki/Line_Friends#BT21 BT21
# /wiki/Line_Friends Line Friends
# /wiki/Mapo_District Mapo-gu
# /wiki/Seoul Seoul
# /wiki/Webtoon webtoons
# /wiki/Line_Webtoon Line Webtoon
# #cite_note-297 [297]
# #cite_note-298 [298]
# #cite_note-299 [299]
# /wiki/Mattel Mattel
# /wiki/Idol_(BTS_song) Idol
# #cite_note-Mattell-261 [261]
# /wiki/Kubrick_(toy) Medicom Toy
# #cite_note-300 [300]
# /wiki/Funko Funko
# #cite_note-301 [301]
# /wiki/Nexon Nexon
# /wiki/Role-playing_game RPG
# /wiki/Elsword Elsword
# #cite_note-302 [302]
# #cite_note-303 [303]
# /wiki/Netmarble_Games Netmarble Games
# #cite_note-304 [304]
# /wiki/KB_Kookmin_Bank KB Kookmin Bank
# #cite_note-305 [305]
# #cite_note-306 [306]
# #cite_note-307 [307]
# /wiki/Coca-Cola_Korea Coca-Cola Korea
# #cite_note-308 [308]
# /wiki/2018_FIFA_World_Cup 2018 World Cup
# #cite_note-309 [309]
# #cite_note-310 [310]
# #cite_note-311 [311]
# #cite_note-312 [312]
# #cite_note-313 [313]
# #cite_note-314 [314]
# /wiki/Love_Myself_(campaign) Love Myself (campaign)
# /wiki/Apgujeong-dong Apgujeong-dong
# #cite_note-Rice_Donation-315 [315]
# #cite_note-Allet_Campaign-316 [316]
# #cite_note-317 [317]
# /wiki/File:BTS_Love_Myself_Logo.png
# /wiki/File:BTS_Love_Myself_Logo.png
# /wiki/Love_Myself_(campaign) Love Myself
# /wiki/Sinking_of_MV_Sewol Sinking of MV Sewol
# #cite_note-Sewol_Donation-318 [318]
# /wiki/Love_Myself_(campaign) Love Myself campaign
# /wiki/UNICEF UNICEF
# #cite_note-319 [319]
# #cite_note-bbun-320 [320]
# #cite_note-321 [321]
# /wiki/Love_Yourself:_Her Love Yourself 承 'Her'
# /wiki/Love_Yourself:_Tear Love Yourself 轉 'Tear'
# /wiki/Love_Yourself:_Answer Love Yourself 結 'Answer'
# #cite_note-bbun-320 [320]
# #cite_note-322 [322]
# #cite_note-323 [323]
# /wiki/Stevie_Wonder Stevie Wonder
# /wiki/Martin_Luther_King_Jr. Martin Luther King Jr.
# #cite_note-324 [324]
# /wiki/Amyotrophic_lateral_sclerosis ALS
# #cite_note-325 [325]
# /wiki/United_Nations United Nations
# /wiki/United_Nations_General_Assembly General Assembly
# #cite_note-RSIUN-250 [250]
# #cite_note-CBSUN-326 [326]
# #cite_note-:13-249 [249]
# #cite_note-RSIUN-250 [250]
# #cite_note-327 [327]
# #cite_note-RSIUN-250 [250]
# #cite_note-CBSUN-326 [326]
# /wiki/Kim_Seok-jin Jin
# #cite_note-328 [328]
# /wiki/J-Hope J-Hope
# /wiki/Suga_(rapper) Suga
# #cite_note-329 [329]
# #cite_note-330 [330]
# /wiki/File:BTS_Universe_logo.png
# /wiki/File:BTS_Universe_logo.png
# /wiki/Parallel_universes_in_fiction alternate universe
# /wiki/Big_Hit_Entertainment Big Hit Entertainment
# /wiki/Webtoon webtoon
# #cite_note-331 [331]
# #cite_note-332 [332]
# /wiki/I_Need_U_(BTS_song) I Need U
# #cite_note-333 [333]
# #cite_note-334 [334]
# #cite_note-335 [335]
# /wiki/The_Ones_Who_Walk_Away_from_Omelas The Ones Who Walk Away from Omelas
# #cite_note-336 [336]
# #cite_note-337 [337]
# #cite_note-338 [338]
# #cite_note-339 [339]
# /wiki/Kim_Seok-jin Jin
# #cite_note-340 [340]
# /wiki/Suga_(rapper) Suga
# #cite_note-341 [341]
# /wiki/J-Hope J-Hope
# #cite_note-342 [342]
# /wiki/RM_(rapper) RM
# #cite_note-343 [343]
# /wiki/Jimin_(singer,_born_1995) Jimin
# #cite_note-344 [344]
# /wiki/V_(singer) V
# #cite_note-345 [345]
# /wiki/Jungkook Jungkook
# #cite_note-346 [346]
# /wiki/BTS_albums_discography BTS albums discography
# /wiki/BTS_songs_discography BTS songs discography
# /wiki/Dark_%26_Wild Dark & Wild
# /wiki/Wings_(BTS_album) Wings
# /wiki/Love_Yourself:_Tear Love Yourself: Tear
# /wiki/Wake_Up_(BTS_album) Wake Up
# /wiki/Youth_(BTS_album) Youth
# /wiki/Face_Yourself Face Yourself
# /wiki/List_of_BTS_concert_tours List of BTS concert tours
# /wiki/2015_BTS_Live_Trilogy_Episode_II:_The_Red_Bullet 2015 BTS Live Trilogy Episode II: The Red Bullet
# /wiki/2017_BTS_Live_Trilogy_Episode_III:_The_Wings_Tour 2017 BTS Live Trilogy Episode III: The Wings Tour
# /wiki/BTS_World_Tour:_Love_Yourself BTS World Tour: Love Yourself
# /wiki/BTS_videography BTS videography
# #cite_note-347 [347]
# #cite_note-348 [348]
# #cite_note-KH1-349 [349]
# /wiki/Burn_the_Stage:_The_Movie Burn the Stage: The Movie
# #cite_note-350 [350]
# /wiki/Love_Yourself_in_Seoul Love Yourself in Seoul
# #cite_note-351 [351]
# /wiki/SBS_MTV SBS MTV
# #cite_note-352 [352]
# /wiki/Mnet_(TV_channel) Mnet
# #cite_note-353 [353]
# #cite_note-354 [354]
# /wiki/Run_BTS! Run BTS!
# /wiki/Mnet_(TV_channel) Mnet
# #cite_note-KH1-349 [349]
# /wiki/YouTube_Premium YouTube Premium
# /wiki/2017_BTS_Live_Trilogy_Episode_III:_The_Wings_Tour Wings tour
# #cite_note-355 [355]
# #cite_note-356 [356]
# /wiki/Run_BTS! Run BTS!
# #cite_note-357 [357]
# #cite_note-358 [358]
# #cite_ref-1 ^
# http://www.universal-music.co.jp/bts/news/2017/03/23/ "シングル「血、汗、涙」を5月10日にリリース！"
# /wiki/Universal_Music_Group Universal Music LLC, Japan
# https://web.archive.org/web/20170324175800/http://www.universal-music.co.jp/bts/news/2017/03/23/ Archived
# #cite_ref-2 ^
# /wiki/Roger_Friedman Friedman, Roger
# http://www.showbiz411.com/2018/08/24/crazy-rich-asians-south-korean-boy-band-bts-first-us-release-explodes-gangnam-style-swamps-itunes-singles-album-charts "Crazy Rich Asians: South Korean Boy Band BTS First US Release Explodes Gangnam Style, Swamps iTunes Singles, Album Charts"
# /wiki/Showbiz411 Showbiz411
# #cite_ref-:9_3-0 a
# #cite_ref-:9_3-1 b
# #cite_ref-:9_3-2 c
# https://web.archive.org/web/20171011234847/https://www.behance.net/gallery/55324473/BTS-Brand-eXperience-Design-Renewal "BTS Brand eXperience Design Renewal"
# /wiki/Behance Behance
# https://www.behance.net/gallery/55324473/BTS-Brand-eXperience-Design-Renewal the original
# #cite_ref-4 ^
# http://www.newsen.com/news_view.php?uid=201506221820303510 "방탄소년단 "팀명 후보, 빅키즈 영네이션 있었다"(야만TV)"
# #cite_ref-5 ^
# http://affinitymagazine.us/2016/05/29/its-about-time-you-know-why-bts-is-trending/ "BTS Is Tackling Problems That Are Taboo"
# #cite_ref-6 ^
# https://www.universal-music.co.jp/bts/ "BTS"
# #cite_ref-newname_7-0 ^
# http://entertain.naver.com/read?oid=009&aid=0003973387 "방탄소년단, 팬클럽 아미와 연결된 새 BI 공개 "문을 열고 나아가는 청춘""
# https://web.archive.org/web/20170812172014/http://entertain.naver.com/read?oid=009&aid=0003973387 Archived
# #cite_ref-8 ^
# https://www.youtube.com/watch?v=p9AutAQ33ro 방탄소년단은 뭐가 달라요?/명견만리플러스
# #cite_ref-:0_9-0 a
# #cite_ref-:0_9-1 b
# /wiki/International_Standard_Book_Number ISBN
# /wiki/Special:BookSources/9791186559116 9791186559116
# #cite_ref-10 ^
# https://www.vox.com/culture/2018/6/13/17426350/bts-history-members-explained "BTS, the band that changed K-pop, explained"
# /wiki/Vox_(website) Vox
# #cite_ref-11 ^
# https://entertain.naver.com/read?oid=001&aid=0004699382 "임정희 "美서 '아메리칸 아이돌' 나가래요"
# #cite_ref-12 ^
# http://star.mt.co.kr/stview.php?no=2010090211500915414 "방시혁, 오디션 통해 힙합그룹 '방탄소년단' 제작"
# https://web.archive.org/web/20170422124040/http://star.mt.co.kr/stview.php?no=2010090211500915414 Archived
# #cite_ref-13 ^
# http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201107130906421116 "'나는 래퍼다' 방시혁, 13년만에 랩 도전"
# https://web.archive.org/web/20170422141636/http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201107130906421116 Archived
# #cite_ref-14 ^
# http://time.com/collection-post/5414052/bts-next-generation-leaders/ "Backed by Passionate Fans, BTS Takes K-Pop Worldwide"
# /wiki/Time_(magazine) Time
# #cite_ref-15 ^
# http://bntnews.co.uk/app/news.php?nid=3882 "New boy group Bulletproof Boy Scouts to hold a debut showcase on June 12"
# https://web.archive.org/web/20150518090435/http://bntnews.co.uk/app/news.php?nid=3882 Archived
# http://mwave.interest.me/enewsworld/en/article/38336/bts-releases-debut-video "[Video] BTS Asks about Your Dreams in 'No More Dream' MV"
# https://web.archive.org/web/20150205172617/http://mwave.interest.me/enewsworld/en/article/38336/bts-releases-debut-video Archived
# #cite_ref-16 ^
# https://web.archive.org/web/20160828194450/http://gaonchart.co.kr/main/section/chart/online.gaon?PageNo=2&nationGbn=T&serviceGbn=ALL&targetTime=25&hitYear=2013&termGbn=week ""2013년 25주차 Digital Chart""
# http://gaonchart.co.kr/main/section/chart/online.gaon?PageNo=2&nationGbn=T&serviceGbn=ALL&targetTime=25&hitYear=2013&termGbn=week the original
# #cite_ref-17 ^
# https://web.archive.org/web/20170707202306/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year "Gaon Yearly Chart: 2013 (see #65)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year the original
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=K&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year "Gaon Yearly Chart: 2014 (Domestic) (see #97)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year "Gaon Yearly Chart: 2015 (see #96)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2016&hitYear=2016&termGbn=year "Gaon 2016년 Album Chart (see #87)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2017&hitYear=2017&termGbn=year "Gaon 2017년 Album Chart (see #98)"
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month "2018년 09월 Album Chart"
# #cite_ref-18 ^
# http://gaonchart.co.kr/main/section/chart/online.gaon?PageNo=2&nationGbn=T&serviceGbn=ALL&targetTime=25&hitYear=2013&termGbn=week "No More Dream"
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=S1020&targetTime=25&hitYear=2013&termGbn=week "Gaon Download Chart June 9-June 15, 2013 (see #84)"
# #cite_ref-BTSReview_19-0 a
# #cite_ref-BTSReview_19-1 b
# #cite_ref-BTSReview_19-2 c
# /wiki/International_Standard_Book_Number ISBN
# /wiki/Special:BookSources/9788925565828 9788925565828
# #cite_ref-:3_20-0 a
# #cite_ref-:3_20-1 b
# #cite_ref-:3_20-2 c
# http://www.ize.co.kr/articleView.html?no=2019040102057238751 "BTS pledges to "tell the story of our generation with our lyrics""
# #cite_ref-:4_21-0 a
# #cite_ref-:4_21-1 b
# http://mosen.mt.co.kr/article/G1109617843 "'엠카' 방탄소년단, 데뷔 무대부터 압도적 '강렬 군무'"
# #cite_ref-22 ^
# http://mosen.mt.co.kr/article/G1109618986 "2AM 정진운, 방탄소년단과 '뮤뱅' 대기실 인증샷 '훈훈'"
# #cite_ref-Japan_Debut_23-0 ^
# http://news.kstyle.com/article.ksn?articleNo=1990114 ""日本デビュー決定"防弾少年団、初めての日本ショーケースを経て韓国カムバックへ…「2年目も今までのように突っ走るだけ"
# #cite_ref-24 ^
# https://web.archive.org/web/20190116184957/http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=38&hitYear=2013&termGbn=week ""2013년 38주차 Digital Chart""
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=38&hitYear=2013&termGbn=week the original
# #cite_ref-25 ^
# https://web.archive.org/web/20170707202306/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year "Gaon 2013년 Album Chart (see #55)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year the original
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year "Gaon 2014년 Album Chart (see #92)"
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year "Gaon 2015년 Album Chart (see #87)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year the original
# http://gaonchart.co.kr/main/section/chart/album.gaon?termGbn=year&hitYear=2016&targetTime=2016&nationGbn=K "Gaon 2016년 Album Chart (see #83)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?termGbn=year&hitYear=2017&targetTime=2017&nationGbn=K "Gaon 2017년 Album Chart – 국내(Domestic) (see #99)"
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month "2018년 09월 Album Chart"
# #cite_ref-26 ^
# /wiki/International_Standard_Book_Number ISBN
# /wiki/Special:BookSources/9788925565828 9788925565828
# #cite_ref-27 ^
# http://www.kwnews.co.kr/nview.asp?s=801&aid=213091100183 "방탄소년단 N.O 발표…"진정한 행복에 대한 메시지""
# #cite_ref-28 ^
# http://sports.chosun.com/news/ntype.htm?id=201308290100252680019119&servicedate=20130828 "방탄소년단, '신인왕 채널방탄'으로 리얼 버라이어티 도전"
# #cite_ref-29 ^
# http://www.melon.com/melonaward/yearlyaward.htm "2013 Melon Music Awards"
# /wiki/Melon_(online_music_service) Melon
# http://isplus.live.joins.com/award/29goldendisc/en/last_winner.aspx?#main_menu "The 28th Golden Disc Awards Winners"
# https://web.archive.org/web/20180224011714/http://isplus.live.joins.com/award/29goldendisc/en/last_winner.aspx?%23main_menu Archived
# http://seoulmusicawards.com/history/winner "23rd Seoul Music Awards Winners"
# https://web.archive.org/web/20180223195443/http://seoulmusicawards.com/history/winner Archived
# #cite_ref-sla_30-0 a
# #cite_ref-sla_30-1 b
# https://www.billboard.com/articles/columns/k-town/8455612/bts-takeover-timeline-bbmas "How BTS Took Over the World: A Timeline of The Group's Biggest Career Moments"
# /wiki/Billboard_(magazine) Billboard
# #cite_ref-31 ^
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year "Gaon Album Chart – 2014 (see #14)"
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year "Gaon Album Chart – 2015 (see #68)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year the original
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2016&hitYear=2016&termGbn=year "Gaon Album Chart – 2016 (see #71)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2017&hitYear=2017&termGbn=year "Gaon Album Chart – 2017 (see #82)"
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month "2018년 09월 Album Chart"
# #cite_ref-World_chart_32-0 ^
# https://www.billboard.com/music/bts/chart-history/world-albums "BTS Album & Song Chart History: World Albums"
# /wiki/Billboard_(magazine) Billboard
# #cite_ref-33 ^
# https://www.youtube.com/watch?v=m8MfJg68oCs [MV] BTS(방탄소년단) _ Boy in Luv(상남자)
# https://web.archive.org/web/20150729070329/https://www.youtube.com/watch?v=m8MfJg68oCs Archived
# http://mwave.interest.me/enewsworld/en/article/62983/bts-releases-mv "[Video] BTS Wishes for 'Just One Day' with You in New MV"
# https://web.archive.org/web/20151121133843/http://mwave.interest.me/enewsworld/en/article/62983/bts-releases-mv Archived
# #cite_ref-34 ^
# /wiki/International_Standard_Book_Number ISBN
# /wiki/Special:BookSources/9788925565828 9788925565828
# #cite_ref-35 ^
# http://www.tvreport.co.kr/?c=news&m=newsview&idx=463054 "[T포토] 방탄소년단 "우리가 바로 상남자!"(엠카운트다운)"
# #cite_ref-36 ^
# http://m.star.naver.com/bts/news/end?id=2612217 "BTS Holds First Fan Club Inauguration Ceremony with 3000 Fans"
# #cite_ref-37 ^
# https://www.billboard.com/articles/news/6157532/bts-announces-free-surprise-los-angeles-concert "BTS Announces Free, Surprise L.A. Concert"
# #cite_ref-38 ^
# http://www.latimes.com/entertainment/music/posts/la-et-ms-girls-generation-bangtan-boys-headline-kcon-2014-20140521-story.html "K-Pop stars Girls' Generation, Bangtan Boys headline KCON 2014"
# https://web.archive.org/web/20141009221756/http://www.latimes.com/entertainment/music/posts/la-et-ms-girls-generation-bangtan-boys-headline-kcon-2014-20140521-story.html Archived
# #cite_ref-39 ^
# https://www.billboard.com/articles/columns/k-town/6214306/kcon-2014-day-2-girls-generation-cnblue-spica-bts-los-angeles-festival "KCON 2014 Day 2: Girls' Generation, CNBLUE, SPICA & More Close L.A. Festival With Loud Bang"
# #cite_ref-40 ^
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year "Gaon Album Chart – 2014 (see #14)"
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year "Gaon Album Chart – 2015 (see #68)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year the original
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&termGbn=year "Gaon Album Chart – 2016 (see #29)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=11&hitYear=2017&termGbn=month "2017년 11월 Album Chart"
# #cite_ref-41 ^
# http://mwave.interest.me/enewsworld/en/article/78799/bts-releases-mv "[Video] BTS Rages in the 'War of Hormone' MV"
# https://web.archive.org/web/20151208071048/http://mwave.interest.me/enewsworld/en/article/78799/bts-releases-mv Archived
# #cite_ref-:15_42-0 a
# #cite_ref-:15_42-1 b
# /wiki/International_Standard_Book_Number ISBN
# /wiki/Special:BookSources/9788925565828 9788925565828
# #cite_ref-43 ^
# http://enter.etoday.co.kr/view/news_view.php?varAtcId=18836 "슈가, "방시혁PD, 미국은 전기 달라 사운드 더 좋다더라" [방탄소년단 기자간담회]"
# #cite_ref-44 ^
# http://news1.kr/articles/?1824877 "'엠카운트다운' 방탄소년단, 카리스마 넘치는 '데인저'로 컴백"
# #cite_ref-TRB_II_45-0 a
# #cite_ref-TRB_II_45-1 b
# http://news.sbs.co.kr/news/endPage.do?news_id=N1003147018&plink=SEARCH&cooper=SBSNEWSSEARCH "방탄소년단, 홍콩 콘서트로 11개월 간 월드투어 '성황리 마무리' 출처"
# https://web.archive.org/web/20170422141734/http://news.sbs.co.kr/news/endPage.do?news_id=N1003147018&plink=SEARCH&cooper=SBSNEWSSEARCH Archived
# #cite_ref-oricon_46-0 ^
# http://www.oricon.co.jp/prof/530375/rank/album/ 防弾少年団のアルバム売上ランキング
# /wiki/Oricon Oricon Style
# https://www.oricon.co.jp/news/2078320/full/ "【オリコン】防弾少年団、アルバム初首位 自己最高売上もマーク"
# /wiki/Oricon Oricon
# #cite_ref-47 ^
# https://itunes.apple.com/jp/album/wake-up-tong-chang-pan/id948185423?l=en "iTunes Preview"
# /wiki/ITunes iTunes
# https://web.archive.org/web/20170422130845/https://itunes.apple.com/jp/album/wake-up-tong-chang-pan/id948185423?l=en Archived
# #cite_ref-48 ^
# http://mwave.interest.me/enewsworld/en/article/87818/bts-wraps-up-concert-tour-in-japan-gathering-25000-fans "BTS Wraps Up Concert Tour in Japan Gathering 25,000 Fans"
# https://web.archive.org/web/20151222111014/http://mwave.interest.me/enewsworld/en/article/87818/bts-wraps-up-concert-tour-in-japan-gathering-25000-fans Archived
# #cite_ref-BTS_Begin_49-0 ^
# http://mwave.interest.me/en/kpop-news/article/87064/video-bts-to-hold-second-exclusive-concert-in-seoul "BTS to Hold Second Exclusive Concert in Seoul"
# https://web.archive.org/web/20170106122508/http://mwave.interest.me/en/kpop-news/article/87064/video-bts-to-hold-second-exclusive-concert-in-seoul Archived
# #cite_ref-Review6_50-0 a
# #cite_ref-Review6_50-1 b
# /wiki/International_Standard_Book_Number ISBN
# /wiki/Special:BookSources/9788925565828 9788925565828
# #cite_ref-:5_51-0 a
# #cite_ref-:5_51-1 b
# http://tenasia.hankyung.com/archives/510280 "방탄소년단이 말하는 '화양연화' (인터뷰①)텐아시아"
# #cite_ref-52 ^
# https://itunes.apple.com/us/album/hwayang-yeonhwa-most-beautiful/id990496954 "The Most Beautiful Moment in Life, Pt. 1 by BTS"
# /wiki/ITunes iTunes
# https://web.archive.org/web/20150518094050/https://itunes.apple.com/us/album/hwayang-yeonhwa-most-beautiful/id990496954 Archived
# #cite_ref-53 ^
# http://www.fuse.tv/2015/06/best-albums-2015-so-far#24 "27 Best Albums We've Heard in 2015 ... So Far #24"
# /wiki/Fuse_(TV_channel) Fuse
# https://web.archive.org/web/20150625213652/http://www.fuse.tv/2015/06/best-albums-2015-so-far#24 Archived
# #cite_ref-54 ^
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year "Gaon 2015년 Album Chart (see #6)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year the original
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2016&hitYear=2016&termGbn=year "Gaon 2016년 Album Chart (see #22)"
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2017&hitYear=2017&termGbn=year "Gaon 2017년 Album Chart (see #60)"
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month "2018년 09월 Album Chart"
# #cite_ref-55 ^
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=19&hitYear=2015&termGbn=week "I Need U"
# #cite_ref-INU_Wins_56-0 ^
# http://osen.mt.co.kr/article/G1110151107 "방탄소년단, '쇼챔피언' 1위..벌써 5개 트로피"
# #cite_ref-57 ^
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=28&hitYear=2015&termGbn=week "쩔어 (Dope)"
# #cite_ref-Dope_100mil_58-0 ^
# http://english.yonhapnews.co.kr/news/2016/10/25/0200000000AEN20161025005300315.html "BTS' 'Dope' music video hits over 100 million views"
# https://web.archive.org/web/20161030095321/http://english.yonhapnews.co.kr/news/2016/10/25/0200000000AEN20161025005300315.html Archived
# #cite_ref-59 ^
# http://www.billboard.com/biz/charts/2015-07-11/world-digital-songs "World Digital Song"
# /wiki/Billboard_(magazine) Billboard
# https://web.archive.org/web/20171103235802/http://www.billboard.com/biz/charts/2015-07-11/world-digital-songs Archived
# #cite_ref-60 ^
# http://www.billboard.com/articles/columns/k-town/7370335/bts-twitter-custom-k-pop-emoji-biggest-fans "BTS Search for Their Biggest Fans on Twitter With K-Pop's First Ever Emoji"
# /wiki/Billboard_(magazine) Billboard
# https://web.archive.org/web/20160616095342/http://www.billboard.com/articles/columns/k-town/7370335/bts-twitter-custom-k-pop-emoji-biggest-fans Archived
# #cite_ref-For_You_Oricon_61-0 ^
# https://web.archive.org/web/20150620105214/https://www.oricon.co.jp/rank/js/d/2015-06-18/ "デイリー　CDシングルランキング 2015年06月18日付"
# /wiki/Oricon Oricon
# https://www.oricon.co.jp/rank/js/d/2015-06-18/ the original
# #cite_ref-62 ^
# http://www.summersonic.com/2015/lineup/ "SUMMER SONIC TOKYO LINE UP – SUMMER SONIC 2015"
# https://web.archive.org/web/20150314181031/http://www.summersonic.com/2015/lineup/ Archived
# #cite_ref-63 ^
# http://mwave.interest.me/enewsworld/en/article/96992/bts-fan-meeting-in-japan-a-roaring-success "BTS Fan Meeting in Japan a Roaring Success"
# https://web.archive.org/web/20150824211118/http://mwave.interest.me/enewsworld/en/article/96992/bts-fan-meeting-in-japan-a-roaring-success Archived
# #cite_ref-64 ^
# http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201510280801961138&ext=na "방탄소년단, 콘서트서 신곡 첫 공개…11월 30일 본격 컴백"
# https://web.archive.org/web/20151031180434/http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201510280801961138&ext=na Archived
# #cite_ref-:16_65-0 a
# #cite_ref-:16_65-1 b
# /wiki/International_Standard_Book_Number ISBN
# /wiki/Special:BookSources/9788925565828 9788925565828
# #cite_ref-66 ^
# ...
# /wiki/Fin.K.L Fin.K.L
# /wiki/Jo_Sung-mo Jo Sung-mo
# /wiki/Kim_Gun-mo Kim Gun-mo
# /wiki/BoA BoA
# /wiki/Lee_Hyori Lee Hyori
# /wiki/Shinhwa Shinhwa
# /wiki/TVXQ TVXQ
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/Wonder_Girls Wonder Girls
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Super_Junior Super Junior
# /wiki/Psy Psy
# /wiki/Exo_(band) Exo
# /wiki/Template:Forbes_Korea_Power_Celebrity v
# /wiki/Template_talk:Forbes_Korea_Power_Celebrity t
# //en.wikipedia.org/w/index.php?title=Template:Forbes_Korea_Power_Celebrity&action=edit e
# /wiki/Forbes_Korea_Power_Celebrity Forbes Korea Power Celebrity
# /wiki/Yuna_Kim Yuna Kim
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/Wonder_Girls Wonder Girls
# /wiki/Lee_Hyori Lee Hyori
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Park_Ji-sung Park Ji-sung
# /wiki/Lee_Seung-yuop Lee Seung-yuop
# /wiki/Rain_(entertainer) Rain
# /wiki/Yoo_Jae-suk Yoo Jae-suk
# /wiki/Kim_Tae-hee Kim Tae-hee
# /wiki/Yuna_Kim Yuna Kim
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Park_Ji-sung Park Ji-sung
# /wiki/Lee_Byung-hun Lee Byung-hun
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/Go_Hyun-jung Go Hyun-jung
# /wiki/Lee_Seung-gi Lee Seung-gi
# /wiki/Lee_Hyori Lee Hyori
# /wiki/Yoo_Jae-suk Yoo Jae-suk
# /wiki/Kang_Ho-dong Kang Ho-dong
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Park_Ji-sung Park Ji-sung
# /wiki/Yuna_Kim Yuna Kim
# /wiki/Lee_Seung-gi Lee Seung-gi
# /wiki/2PM 2PM
# /wiki/Yoo_Jae-suk Yoo Jae-suk
# /wiki/Lee_Chung-yong Lee Chung-yong
# /wiki/2AM_(band) 2AM
# /wiki/Shin-Soo_Choo Shin-Soo Choo
# /wiki/Kang_Ho-dong Kang Ho-dong
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/IU_(singer) IU
# /wiki/Kara_(South_Korean_band) Kara
# /wiki/Yuna_Kim Yuna Kim
# /wiki/Lee_Seung-gi Lee Seung-gi
# /wiki/Park_Ji-sung Park Ji-sung
# /wiki/Kim_Tae-hee Kim Tae-hee
# /wiki/Beast_(South_Korean_band) Beast
# /wiki/Park_Tae-hwan Park Tae-hwan
# /wiki/Psy Psy
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Son_Yeon-jae Son Yeon-jae
# /wiki/Kim_Soo-hyun Kim Soo-hyun
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/Park_Tae-hwan Park Tae-hwan
# /wiki/Song_Joong-ki Song Joong-ki
# /wiki/IU_(singer) IU
# /wiki/Yuna_Kim Yuna Kim
# /wiki/Super_Junior Super Junior
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/Bae_Suzy Suzy
# /wiki/Hyun-jin_Ryu Hyun-jin Ryu
# /wiki/Exo_(band) Exo
# /wiki/Shin-Soo_Choo Shin-Soo Choo
# /wiki/TVXQ TVXQ
# /wiki/Shinee Shinee
# /wiki/Yuna_Kim Yuna Kim
# /wiki/IU_(singer) IU
# /wiki/Exo_(band) Exo
# /wiki/Kim_Soo-hyun Kim Soo-hyun
# /wiki/Yuna_Kim Yuna Kim
# /wiki/Jun_Ji-hyun Jun Ji-hyun
# /wiki/Son_Yeon-jae Son Yeon-jae
# /wiki/Lee_Seung-gi Lee Seung-gi
# /wiki/Hyun-jin_Ryu Hyun-jin Ryu
# /wiki/Son_Heung-min Son Heung-min
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Sistar Sistar
# /wiki/Exo_(band) Exo
# /wiki/Yoo_Ah-in Yoo Ah-in
# /wiki/Lee_Hye-ri Hye-ri
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Kim_Soo-hyun Kim Soo-hyun
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/Inbee_Park Inbee Park
# /wiki/Jun_Ji-hyun Jun Ji-hyun
# /wiki/IU_(singer) IU
# /wiki/Jung-ho_Kang Jung-ho Kang
# /wiki/Park_Bo-gum Park Bo-gum
# /wiki/Song_Joong-ki Song Joong-ki
# /wiki/Twice_(band) Twice
# /wiki/Exo_(band) Exo
# /wiki/Bae_Suzy Suzy
# /wiki/Song_Hye-kyo Song Hye-kyo
# /wiki/Kim_Yoo-jung Kim Yoo-jung
# /wiki/Jo_Jung-suk Jo Jung-suk
# /wiki/Seung-hwan_Oh Seung-hwan Oh
# /wiki/Wanna_One Wanna One
# /wiki/Twice_(band) Twice
# /wiki/Exo_(band) Exo
# /wiki/IU_(singer) IU
# /wiki/Song_Hye-kyo Song Hye-kyo
# /wiki/Song_Joong-ki Song Joong-ki
# /wiki/Park_Bo-gum Park Bo-gum
# /wiki/Yuna_Kim Yuna Kim
# /wiki/Hyun-jin_Ryu Hyun-jin Ryu
# /wiki/Template:Mnet_Asian_Music_Award_for_Album_of_the_Year v
# /w/index.php?title=Template_talk:Mnet_Asian_Music_Award_for_Album_of_the_Year&action=edit&redlink=1 t
# //en.wikipedia.org/w/index.php?title=Template:Mnet_Asian_Music_Award_for_Album_of_the_Year&action=edit e
# /wiki/Mnet_Asian_Music_Award_for_Album_of_the_Year Mnet Asian Music Award for Album of the Year
# /wiki/The_3rd_Masterpiece The 3rd Masterpiece
# /wiki/SG_Wannabe SG Wannabe
# /wiki/Remapping_the_Human_Soul Remapping the Human Soul
# /wiki/Epik_High Epik High
# /wiki/Mirotic Mirotic
# /wiki/TVXQ TVXQ
# /wiki/Heartbreaker_(G-Dragon_album) Heartbreaker
# /wiki/G-Dragon G-Dragon
# /wiki/To_Anyone To Anyone
# /wiki/2NE1 2NE1
# /wiki/Mr._Simple Mr. Simple
# /wiki/Super_Junior Super Junior
# /wiki/Sexy,_Free_%26_Single Sexy, Free & Single
# /wiki/Super_Junior Super Junior
# /wiki/XOXO_(album) XOXO
# /wiki/Exo_(band) Exo
# /wiki/Overdose_(EP) Overdose
# /wiki/Exo_(band) Exo
# /wiki/Exodus_(Exo_album) Exodus
# /wiki/Exo_(band) Exo
# /wiki/Ex%27Act Ex'Act
# /wiki/Exo_(band) Exo
# /wiki/The_War_(album) The War
# /wiki/Exo_(band) Exo
# /wiki/Love_Yourself:_Tear Love Yourself: Tear
# /wiki/Template:Mnet_Asian_Music_Award_for_Artist_of_the_Year v
# /wiki/Template_talk:Mnet_Asian_Music_Award_for_Artist_of_the_Year t
# //en.wikipedia.org/w/index.php?title=Template:Mnet_Asian_Music_Award_for_Artist_of_the_Year&action=edit e
# /wiki/Mnet_Asian_Music_Award_for_Artist_of_the_Year Mnet Asian Music Award for Artist of the Year
# /wiki/TVXQ TVXQ
# /wiki/Super_Junior Super Junior
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/2PM 2PM
# /wiki/2NE1 2NE1
# /wiki/Girls%27_Generation Girls' Generation
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/G-Dragon G-Dragon
# /wiki/Exo_(band) Exo
# /wiki/Big_Bang_(South_Korean_band) Big Bang
# /wiki/Template:Big_Hit_Entertainment v
# /wiki/Template_talk:Big_Hit_Entertainment t
# //en.wikipedia.org/w/index.php?title=Template:Big_Hit_Entertainment&action=edit e
# /wiki/Big_Hit_Entertainment Big Hit Entertainment
# /wiki/Big_Hit_Entertainment_Discography Discography
# /wiki/Bang_Si-hyuk Bang Si-hyuk
# /wiki/Suga_(entertainer) Agust D
# /wiki/J-Hope J-Hope
# /wiki/Lee_Hyun Lee Hyun
# /wiki/RM_(rapper) RM
# /wiki/TXT_(band) TXT
# /wiki/2AM_(band) 2AM
# /wiki/8Eight 8Eight
# /wiki/Glam_(band) GLAM
# /wiki/Lim_Jeong-hee Lim Jeong-hee
# /wiki/Homme_(band) Homme
# /wiki/Lee_Chang-min_(singer) Lee Changmin
# /wiki/Signal_Entertainment_Group Signal Entertainment Group
# /wiki/Kakao_M Kakao M
# /wiki/Iriver_Inc Iriver Inc
# /wiki/K-pop K-pop
# /wiki/Category:South_Korean_record_labels Korean record labels
# /wiki/Help:Authority_control Authority control
# https://www.wikidata.org/wiki/Q13580495
# /wiki/Library_of_Congress_Control_Number LCCN
# https://id.loc.gov/authorities/names/no2017138930 no2017138930
# /wiki/MusicBrainz MusicBrainz
# https://musicbrainz.org/artist/0d79fe8e-ba27-4859-bb8c-2f255f346853 0d79fe8e-ba27-4859-bb8c-2f255f346853
# /wiki/WorldCat_Identities WorldCat Identities
# https://www.worldcat.org/identities/lccn-no2017-138930 no2017-138930
# https://en.wikipedia.org/w/index.php?title=BTS_(band)&oldid=894700997 https://en.wikipedia.org/w/index.php?title=BTS_(band)&oldid=894700997
# /wiki/Help:Category Categories
# /wiki/Category:BTS_(band) BTS (band)
# /wiki/Category:2013_establishments_in_South_Korea 2013 establishments in South Korea
# /wiki/Category:K-pop_music_groups K-pop music groups
# /wiki/Category:Melon_Music_Award_winners Melon Music Award winners
# /wiki/Category:Mnet_Asian_Music_Award_winners Mnet Asian Music Award winners
# /wiki/Category:Musical_groups_established_in_2013 Musical groups established in 2013
# /wiki/Category:Musical_groups_from_Seoul Musical groups from Seoul
# /wiki/Category:South_Korean_boy_bands South Korean boy bands
# /wiki/Category:South_Korean_dance_music_groups South Korean dance music groups
# /wiki/Category:South_Korean_hip_hop_groups South Korean hip hop groups
# /wiki/Category:Columbia_Records_artists Columbia Records artists
# /wiki/Category:Recipients_of_the_Order_of_Cultural_Merit_(Korea) Recipients of the Order of Cultural Merit (Korea)
# /wiki/Category:CS1_Korean-language_sources_(ko) CS1 Korean-language sources (ko)
# /wiki/Category:CS1_Japanese-language_sources_(ja) CS1 Japanese-language sources (ja)
# /wiki/Category:CS1_uses_Japanese-language_script_(ja) CS1 uses Japanese-language script (ja)
# /wiki/Category:CS1_uses_Korean-language_script_(ko) CS1 uses Korean-language script (ko)
# /wiki/Category:CS1_Indonesian-language_sources_(id) CS1 Indonesian-language sources (id)
# /wiki/Category:CS1_Italian-language_sources_(it) CS1 Italian-language sources (it)
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages Wikipedia indefinitely semi-protected pages
# /wiki/Category:Use_mdy_dates_from_January_2019 Use mdy dates from January 2019
# /wiki/Category:Articles_with_short_description Articles with short description
# /wiki/Category:Use_American_English_from_July_2018 Use American English from July 2018
# /wiki/Category:All_Wikipedia_articles_written_in_American_English All Wikipedia articles written in American English
# /wiki/Category:Use_mdy_dates_from_September_2018 Use mdy dates from September 2018
# /wiki/Category:Articles_containing_Korean-language_text Articles containing Korean-language text
# /wiki/Category:Articles_containing_Japanese-language_text Articles containing Japanese-language text
# /wiki/Category:Articles_with_hCards Articles with hCards
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2019 Articles containing potentially dated statements from 2019
# /wiki/Category:All_articles_containing_potentially_dated_statements All articles containing potentially dated statements
# /wiki/Category:Commons_category_link_is_on_Wikidata Commons category link is on Wikidata
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers Wikipedia articles with LCCN identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers Wikipedia articles with MusicBrainz identifiers
# /wiki/Category:Wikipedia_articles_with_WorldCat-LCCN_identifiers Wikipedia articles with WorldCat-LCCN identifiers
# /wiki/Special:MyTalk Talk
# /wiki/Special:MyContributions Contributions
# /w/index.php?title=Special:CreateAccount&returnto=BTS+%28band%29 Create account
# /w/index.php?title=Special:UserLogin&returnto=BTS+%28band%29 Log in
# /wiki/BTS_(band) Article
# /wiki/Talk:BTS_(band) Talk
# /wiki/BTS_(band) Read
# /w/index.php?title=BTS_(band)&action=edit View source
# /w/index.php?title=BTS_(band)&action=history View history
# /wiki/Main_Page
# /wiki/Main_Page Main page
# /wiki/Portal:Contents Contents
# /wiki/Portal:Featured_content Featured content
# /wiki/Portal:Current_events Current events
# /wiki/Special:Random Random article
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en Donate to Wikipedia
# //shop.wikimedia.org Wikipedia store
# /wiki/Help:Contents Help
# /wiki/Wikipedia:About About Wikipedia
# /wiki/Wikipedia:Community_portal Community portal
# /wiki/Special:RecentChanges Recent changes
# //en.wikipedia.org/wiki/Wikipedia:Contact_us Contact page
# /wiki/Special:WhatLinksHere/BTS_(band) What links here
# /wiki/Special:RecentChangesLinked/BTS_(band) Related changes
# /wiki/Wikipedia:File_Upload_Wizard Upload file
# /wiki/Special:SpecialPages Special pages
# /w/index.php?title=BTS_(band)&oldid=894700997 Permanent link
# /w/index.php?title=BTS_(band)&action=info Page information
# https://www.wikidata.org/wiki/Special:EntityPage/Q13580495 Wikidata item
# /w/index.php?title=Special:CiteThisPage&page=BTS_%28band%29&id=894700997 Cite this page
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=BTS+%28band%29 Create a book
# /w/index.php?title=Special:ElectronPdf&page=BTS+%28band%29&action=show-download-screen Download as PDF
# /w/index.php?title=BTS_(band)&printable=yes Printable version
# https://commons.wikimedia.org/wiki/Category:BTS_(musical_group) Wikimedia Commons
# https://ar.wikipedia.org/wiki/%D8%A8%D9%8A_%D8%AA%D9%8A_%D8%A3%D8%B3 العربية
# https://ast.wikipedia.org/wiki/BTS_(grupu_musical) Asturianu
# https://az.wikipedia.org/wiki/BTS_(musiqi_qrupu) Azərbaycanca
# https://zh-min-nan.wikipedia.org/wiki/BTS Bân-lâm-gú
# https://bg.wikipedia.org/wiki/%D0%91%D0%B8_%D0%A2%D0%B8_%D0%95%D1%81 Български
# https://ca.wikipedia.org/wiki/BTS_(Grup_de_K-Pop) Català
# https://cs.wikipedia.org/wiki/BTS_(hudebn%C3%AD_skupina) Čeština
# https://cy.wikipedia.org/wiki/BTS Cymraeg
# https://da.wikipedia.org/wiki/BTS_(musikgruppe) Dansk
# https://de.wikipedia.org/wiki/BTS_(Band) Deutsch
# https://et.wikipedia.org/wiki/BTS Eesti
# https://el.wikipedia.org/wiki/BTS_(%CF%83%CF%85%CE%B3%CE%BA%CF%81%CF%8C%CF%84%CE%B7%CE%BC%CE%B1) Ελληνικά
# https://es.wikipedia.org/wiki/BTS_(banda) Español
# https://eu.wikipedia.org/wiki/BTS Euskara
# https://fa.wikipedia.org/wiki/%D8%A8%DB%8C%E2%80%8C%D8%AA%DB%8C%E2%80%8C%D8%A7%D8%B3_(%DA%AF%D8%B1%D9%88%D9%87_%D9%85%D9%88%D8%B3%DB%8C%D9%82%DB%8C) فارسی
# https://fr.wikipedia.org/wiki/BTS_(groupe) Français
# https://gl.wikipedia.org/wiki/BTS_(grupo_musical) Galego
# https://hak.wikipedia.org/wiki/F%C3%B2ng-th%C3%A0n_S%C3%A9u-ngi%C3%A8n-th%C3%B2n 客家語/Hak-kâ-ngî
# https://ko.wikipedia.org/wiki/%EB%B0%A9%ED%83%84%EC%86%8C%EB%85%84%EB%8B%A8 한국어
# https://hy.wikipedia.org/wiki/BTS Հայերեն
# https://hi.wikipedia.org/wiki/%E0%A4%AC%E0%A5%80%E0%A4%9F%E0%A5%80%E0%A4%8F%E0%A4%B8_(%E0%A4%AC%E0%A5%88%E0%A4%A8%E0%A5%8D%E0%A4%A1) हिन्दी
# https://id.wikipedia.org/wiki/BTS_(grup_musik) Bahasa Indonesia
# https://it.wikipedia.org/wiki/BTS_(gruppo_musicale) Italiano
# https://he.wikipedia.org/wiki/BTS עברית
# https://pam.wikipedia.org/wiki/Bangtan_Boys Kapampangan
# https://ka.wikipedia.org/wiki/BTS_(%E1%83%AF%E1%83%92%E1%83%A3%E1%83%A4%E1%83%98) ქართული
# https://kk.wikipedia.org/wiki/BTS Қазақша
# https://lv.wikipedia.org/wiki/BTS Latviešu
# https://lt.wikipedia.org/wiki/BTS Lietuvių
# https://hu.wikipedia.org/wiki/BTS_(egy%C3%BCttes) Magyar
# https://ms.wikipedia.org/wiki/BTS_(kumpulan_muzik) Bahasa Melayu
# https://mn.wikipedia.org/wiki/Bangtan_Boys Монгол
# https://nl.wikipedia.org/wiki/BTS_(band) Nederlands
# https://ja.wikipedia.org/wiki/%E9%98%B2%E5%BC%BE%E5%B0%91%E5%B9%B4%E5%9B%A3 日本語
# https://no.wikipedia.org/wiki/BTS_(band) Norsk
# https://km.wikipedia.org/wiki/BTS_(band) ភាសាខ្មែរ
# https://pl.wikipedia.org/wiki/BTS_(zesp%C3%B3%C5%82_muzyczny) Polski
# https://pt.wikipedia.org/wiki/BTS Português
# https://ro.wikipedia.org/wiki/BTS_(trup%C4%83) Română
# https://ru.wikipedia.org/wiki/BTS Русский
# https://sco.wikipedia.org/wiki/BTS_(baund) Scots
# https://sq.wikipedia.org/wiki/Bangtan_Boys Shqip
# https://sk.wikipedia.org/wiki/BTS_(skupina) Slovenčina
# https://sl.wikipedia.org/wiki/BTS_(glasbena_skupina) Slovenščina
# https://sr.wikipedia.org/wiki/%D0%91%D0%A2%D0%A1_(%D0%B1%D0%B5%D0%BD%D0%B4) Српски / srpski
# https://fi.wikipedia.org/wiki/BTS_(yhtye) Suomi
# https://sv.wikipedia.org/wiki/BTS_(musikgrupp) Svenska
# https://tl.wikipedia.org/wiki/Bangtan_Boys Tagalog
# https://th.wikipedia.org/wiki/%E0%B8%9A%E0%B8%B5%E0%B8%97%E0%B8%B5%E0%B9%80%E0%B8%AD%E0%B8%AA_(%E0%B8%81%E0%B8%A5%E0%B8%B8%E0%B9%88%E0%B8%A1%E0%B8%99%E0%B8%B1%E0%B8%81%E0%B8%A3%E0%B9%89%E0%B8%AD%E0%B8%87) ไทย
# https://tr.wikipedia.org/wiki/BTS_(m%C3%BCzik_grubu) Türkçe
# https://uk.wikipedia.org/wiki/BTS Українська
# https://vep.wikipedia.org/wiki/BTS Vepsän kel’
# https://vi.wikipedia.org/wiki/BTS_(nh%C3%B3m_nh%E1%BA%A1c) Tiếng Việt
# https://fiu-vro.wikipedia.org/wiki/BTS Võro
# https://zh-yue.wikipedia.org/wiki/%E9%98%B2%E5%BD%88%E5%B0%91%E5%B9%B4%E5%9C%98 粵語
# https://zh.wikipedia.org/wiki/%E9%98%B2%E5%BD%88%E5%B0%91%E5%B9%B4%E5%9C%98 中文
# https://www.wikidata.org/wiki/Special:EntityPage/Q13580495#sitelinks-wikipedia Edit links
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License Creative Commons Attribution-ShareAlike License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use Terms of Use
# //foundation.wikimedia.org/wiki/Privacy_policy Privacy Policy
# //www.wikimediafoundation.org/ Wikimedia Foundation, Inc.
# https://foundation.wikimedia.org/wiki/Privacy_policy Privacy policy
# /wiki/Wikipedia:About About Wikipedia
# /wiki/Wikipedia:General_disclaimer Disclaimers
# //en.wikipedia.org/wiki/Wikipedia:Contact_us Contact Wikipedia
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute Developers
# https://foundation.wikimedia.org/wiki/Cookie_statement Cookie statement
# //en.m.wikipedia.org/w/index.php?title=BTS_(band)&mobileaction=toggle_view_mobile Mobile view
# https://wikimediafoundation.org/
# //www.mediawiki.org/
